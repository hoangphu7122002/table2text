# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

data_link = "/content/drive/MyDrive/largeProject/code/combine/saved_dictionary.pkl"

with open(data_link, 'rb') as f:
    loaded_dict = pickle.load(f)

# %%
print(loaded_dict.keys())
print(loaded_dict['01/2020'].keys())
print(loaded_dict['01/2020']['month'].keys())
print(loaded_dict['01/2020']['month']['VTS'].keys())
# Out:
# dict_keys(['01/2020', '02/2020', '03/2020', '04/2020', '05/2020', '06/2020', '07/2020', '08/2020', '09/2020', '10/2020', '11/2020', '12/2020', '01/2021', '02/2021', '03/2021', '04/2021', '05/2021', '06/2021', '07/2021', '08/2021', '09/2021', '10/2021', '11/2021', '12/2021', '01/2022', '02/2022', '03/2022', '04/2022', '05/2022', '06/2022', '07/2022', '08/2022', '09/2022', '10/2022', '11/2022', '12/2022', '01/2023', '02/2023', '03/2023', '04/2023', '05/2023', '06/2023'])
# dict_keys(['month', 'quarter', 'year'])
# dict_keys(['VTT', 'VTS', 'VDS', 'VTPOST'])
# dict_keys(['Tổng đài 18008000', 'Tổng đài 19009095', 'PAKH/1000 thuê bao/ngày dịch vụ Kênh truyền', 'PAKH/10.000 thuê bao/ngày dịch vụ GP CNTT', 'Thời gian trung bình xử lý sự cố dịch vụ kênh truyền', 'Thời gian trung bình xử lý phản ánh dịch vụ Giải pháp CNTT', 'Xử lý PAKH dịch vụ Kênh truyền - Xử lý sự cố trong hạn 3 giờ', 'Xử lý PAKH dịch vụ Kênh truyền - Xử lý PAKH trong hạn 24 giờ', 'Xử lý PAKH dịch vụ Kênh truyền - Xử lý PAKH trong hạn 48 giờ', 'Xử lý PAKH dịch vụ ứng dụng CNTT', 'Mức độ hài lòng dịch vụ Kênh truyền (CSAT)', 'Mức độ hài lòng dịch vụ chuyển đổi số cho KH doanh nghiệp lớn và chính phủ (CSAT)'])

# %%
loaded_dict['01/2020']['month']['VTS']['Tổng đài 18008000']
# Out:
# {'View': 'Tháng',
#  'Time': '01/2020',
#  'CHỈ TIÊU': 'Tổng đài 18008000',
#  'ĐƠN VỊ': '%',
#  'ĐIỀU KIỆN': '>=',
#  'KPI mục tiêu tháng': 93.4,
#  'Tháng 1.2020': 82.4,
#  'Đánh giá': 'Không đạt',
#  'T12.2019': 97.2,
#  'So sánh T12.2019 Tăng giảm': -14.8,
#  'T1.2019': 81.8,
#  'So sánh T1.2019 Tăng giảm': 0.6,
#  'TỔNG CÔNG TY': 'VTS',
#  'KPI MẸ': 'Tỷ lệ kết nối thành công đến tổng đài'}

# %%
loaded_dict['01/2020']['month']['VTS']['PAKH/1000 thuê bao/ngày dịch vụ Kênh truyền']
# Out:
# {'View': 'Tháng',
#  'Time': '01/2020',
#  'CHỈ TIÊU': 'PAKH/1000 thuê bao/ngày dịch vụ Kênh truyền',
#  'ĐƠN VỊ': 'Phản ánh',
#  'ĐIỀU KIỆN': '<=',
#  'KPI mục tiêu tháng': 11.3,
#  'Tháng 1.2020': 10.5,
#  'Đánh giá': 'Đạt',
#  'T12.2019': 11.3,
#  'So sánh T12.2019 Tăng giảm': -0.8,
#  'T1.2019': 5.8,
#  'So sánh T1.2019 Tăng giảm': 4.7,
#  'TỔNG CÔNG TY': 'VTS',
#  'KPI MẸ': 'Tỷ lệ phản ánh khiếu nại của Khách hàng'}
