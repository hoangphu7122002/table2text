# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install datasets evaluate transformers rouge-score nltk
# !pip install accelerate -U
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"
# !pip install py_vncorenlp
# !pip install pytorch-crf
# !pip install -U sentence-transformers
# !pip install tensorflow_addons
# !pip install gensim==4.1.2

# %%
import sys
sys.path.append('/content/drive/MyDrive/largeProject/code/combine/v1_script.py')

# %%
# %cd /content/drive/MyDrive/largeProject/code/combine/
from v1_script import *
# Out:
# /content/drive/MyDrive/largeProject/code/combine
# Append /content/drive/MyDrive/largeProject/code to sys.path
# VnCoreNLP model folder /content already exists! Please load VnCoreNLP from this folder!
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
module_response("tình hình biến động đến tháng 11/2022 của chỉ tiêu chỉ tiêu Lỗi SME - vTracking hiện ra sao",3)
# Out:
# 1/1 [==============================] - 2s 2s/step
# intent là: viewStat - passage 1
# intent là: viewDetermineTrend - passage 2
# intent là: oneKPI - passage 3
# ['Vào thời điểm hiện tại, chỉ số Lỗi SME - vTracking của tổng công ty VTT trong tháng 11 của 3 năm gần nhất đã được đánh giá và có 1 lần đạt và 2 lần không đạt. Cụ thể ta có thể nhìn thấy:\nT11/2022 đạt được KPI là: 87.7% được đánh giá là Không đạt\nT11/2021 đạt được KPI là: 82.7% được đánh giá là Không đạt\nT11/2020 đạt được KPI là: 94.6% được đánh giá là Đạt',
#  'dựa vào kết quả hiện có tính đến T11/2022 của chỉ tiêu Lỗi SME - vTracking thì trend hiện có xu hướng không sai khác quá nhiều ',
#  'Chỉ tiêu Lỗi SME - vTracking với hiện trạng có kết quả là 87.7%, giảm 1.9% so với mục tiêu kpi là 89.6%. Bên cạnh đó trong khi t10/2022 đạt 80.8%, tăng 1.9%, gấp 0.98 lần. Cùng kỳ năm trước chỉ tiêu có được là 82.7% tăng 5.0%']

# %%
module_response("cho tôi biết tình hình tổng quan của nhóm chỉ tiêu Tiến độ xử lý phản ánh của KH của tổng công ty VTT quý 4 năm 2022",3)
# Out:
# 1/1 [==============================] - 0s 117ms/step
# intent là: groupMonthOverall - passage 1
# intent là: groupMonthDetail - passage 2
# intent là: viewOneGroupKPIStat - passage 3
# ['Với n2022, cụm chỉ tiêu "Tiến độ xử lý phản ánh của KH  (BO)" tính đến tháng 2 năm 2022 với đơn vị % và điều kiện >= có số chỉ tiêu con là 6, tên và kết quả tương ứng lần lượt là: \n+ chỉ tiêu "clm vô tuyến - tỷ lệ hoàn thành xử lý pakh về clm trong hạn" có kết quả là: không đạt\n+ chỉ tiêu "lỗi dịch vụ cố định (gpon ftth/ths) - tỷ lệ xử lý trong hạn" có kết quả là: đạt\n+ chỉ tiêu "lỗi sme - viettel ca" có kết quả là: đạt\n+ chỉ tiêu "lỗi sme - vbhxh" có kết quả là: không đạt\n+ chỉ tiêu "lỗi sme - hóa đơn điện tử" có kết quả là: đạt\n+ chỉ tiêu "lỗi sme - vtracking" có kết quả là: không đạt',
# ...

# %%
module_response("tình hình biến động đến tháng 10/2022 của chỉ tiêu chỉ tiêu Lỗi SME - vTracking hiện ra sao",3)
# Out:
# 1/1 [==============================] - 0s 122ms/step
# intent là: viewStat - passage 1
# intent là: viewDetermineTrend - passage 2
# intent là: oneKPI - passage 3
# ['hiện tại tình hình của chỉ tiêu Lỗi SME - vTracking của tổng công ty VTT trong năm 2022 đạt được đánh giá là đạt bao gồm 0 lần và không đạt là 9 lần. Cụ thể ta có thể nhìn thấy:\nT1/2022 đạt được KPI là: 81.9% được đánh giá là Không đạt\nT2/2022 đạt được KPI là: 91.9% được đánh giá là Không đạt\nT3/2022 đạt được KPI là: 80.9% được đánh giá là Không đạt\nT4/2022 đạt được KPI là: 87.4% được đánh giá là Không đạt\nT5/2022 đạt được KPI là: 81.3% được đánh giá là Không đạt\nT6/2022 đạt được KPI là: 82.4% được đánh giá là Không đạt\nT7/2022 đạt được KPI là: 84.4% được đánh giá là Không đạt\nT8/2022 đạt được KPI là: 85.8% được đánh giá là Không đạt\nT9/2022 đạt được KPI là: 84.3% được đánh giá là Không đạt',
#  'dựa vào kết quả hiện có tính đến T10/2022 của chỉ tiêu Lỗi SME - vTracking thì trend hiện có xu hướng giảm chậm',
# ...

# %%
module_response("trong tháng 3 năm 2023, chỉ tiêu Mức độ hài lòng dịch vụ Kênh truyền (CSAT) thuộc chỉ tiêu mẹ nào",3)
# Out:
# 1/1 [==============================] - 0s 235ms/step
# intent là: ChildInferenceMom - passage 1
# intent là: viewDetermineTrend - passage 2
# ['Chỉ tiêu Mức độ hài lòng dịch vụ Kênh truyền (CSAT) trong t3/2023 hiện trạng đạt được 80.3% thuộc về chỉ tiêu mẹ Mức độ hài lòng (theo từng dịch vụ trọng điểm) của tổng công ty VTS. Trong cùng năm, chỉ tiêu này có số KPI không đạt là 1, số KPI đạt là 1 và dự đoán tháng tiếp theo có thể đạt với mức kết quả là: 86.45%.',
#  'dựa vào kết quả hiện có tính đến T3/2023 của chỉ tiêu Mức độ hài lòng dịch vụ Kênh truyền (CSAT) thì trend hiện có xu hướng giảm chậm']
