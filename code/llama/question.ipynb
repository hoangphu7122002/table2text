# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

# %%
link_data = "/content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad "

# %%
import os

for a in sorted(os.listdir(link_data)):
  print(link_data + f"/{a}")
# Out:
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_0.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_1000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_10000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_11000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_12000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_13000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_14000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_15000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_16000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_17000.csv
# /content/drive/MyDrive/largeProject/code/LLM training/Splitted Visquad /df_gen_18000.csv
# ...
